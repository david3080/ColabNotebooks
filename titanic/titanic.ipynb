# %% [markdown]
# タイタニック号の乗客のうち、生き残った乗客の属性を決定木の手法を使って分析してみます。

# %% [markdown]
# まずは、タイタニック号の乗客情報を読み込みます。

# %%
import pandas as pd
train = pd.read_csv("https://raw.githubusercontent.com/david3080/ColabNotebooks/master/titanic/train.csv")
test = pd.read_csv("https://raw.githubusercontent.com/david3080/ColabNotebooks/master/titanic/test.csv")

# %% [markdown]
# タイタニック号乗客情報の学習用データとして用意したデータ（train）を表でリストします

# %%
train

# %% [markdown]
# タイタニック号乗客情報の学習用データとして用意したデータ（train）の属性名をリストして属性数をカウントします（表の一番上の行に表示された属性名）

# %%
# 属性名のリスト
train.columns
# Out:
# Index(['乗客ID', '生死', '客室クラス', '名前', '性別', '年齢', '兄弟配偶者の数', '両親子供の数', 'チケット番号',
#        '乗船料金', '部屋番号', '乗船した港'],
#       dtype='object')

# %%
# 属性数
len(train.columns)
# Out:
# 12

# %% [markdown]
# 乗客数を数えます（表の列を数えます）

# %%
len(train)
# Out:
# 891

# %% [markdown]
# 表に含まれる全要素数を数えます

# %%
train.size
# Out:
# 10692
