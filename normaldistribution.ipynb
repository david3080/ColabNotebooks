# %% [markdown]
# 100枚のコインを同時に投げて、表と裏の数がN:100-N（N=0...100）となる組み合わせ数はcomb(100,N)となるので、それぞれ起こりうる確率はcomb(100,N)/2**100となる。
#
# これをグラフに表現する。

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

N = 100
x = range(0, N+1, 1) # 1〜N回表が出るケースと0回のケースがあるので、N+1通りのケースがある
y1 = scm.comb(N, x) / 2**100
y2 = norm.pdf(x,50,25)

plt.plot(y1)
plt.show()

plt.plot(y2)
plt.show()
